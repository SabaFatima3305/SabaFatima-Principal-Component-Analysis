# %%
import pandas as pd
df = pd.read_csv("C:/Users/ASUS/OneDrive/Documents/data science/DS Assignments/PCA/wine.csv")
df
# Out:
#      Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0       1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1       1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2       1    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3       1    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4       1    13.24   2.59  2.87        21.0        118     2.80        2.69
# ..    ...      ...    ...   ...         ...        ...      ...         ...
# 173     3    13.71   5.65  2.45        20.5         95     1.68        0.61
# 174     3    13.40   3.91  2.48        23.0        102     1.80        0.75
# 175     3    13.27   4.28  2.26        20.0        120     1.59        0.69
# 176     3    13.17   2.59  2.37        20.0        120     1.65        0.68
# 177     3    14.13   4.10  2.74        24.5         96     2.05        0.76
#
# ...

# %% [markdown]
# ## Data Preprocessing

# %%
df.shape
# Out:
# (178, 14)

# %%
df.isnull().sum()
# Out:
# Type               0
# Alcohol            0
# Malic              0
# Ash                0
# Alcalinity         0
# Magnesium          0
# Phenols            0
# Flavanoids         0
# Nonflavanoids      0
# Proanthocyanins    0
# Color              0
# Hue                0
# Dilution           0
# Proline            0
# dtype: int64

# %%
df.corr()
# Out:
#                      Type   Alcohol     Malic       Ash  Alcalinity  \
# Type             1.000000 -0.328222  0.437776 -0.049643    0.517859
# Alcohol         -0.328222  1.000000  0.094397  0.211545   -0.310235
# Malic            0.437776  0.094397  1.000000  0.164045    0.288500
# Ash             -0.049643  0.211545  0.164045  1.000000    0.443367
# Alcalinity       0.517859 -0.310235  0.288500  0.443367    1.000000
# Magnesium       -0.209179  0.270798 -0.054575  0.286587   -0.083333
# Phenols         -0.719163  0.289101 -0.335167  0.128980   -0.321113
# Flavanoids      -0.847498  0.236815 -0.411007  0.115077   -0.351370
# Nonflavanoids    0.489109 -0.155929  0.292977  0.186230    0.361922
# Proanthocyanins -0.499130  0.136698 -0.220746  0.009652   -0.197327
# Color            0.265668  0.546364  0.248985  0.258887    0.018732
# Hue             -0.617369 -0.071747 -0.561296 -0.074667   -0.273955
# Dilution        -0.788230  0.072343 -0.368710  0.003911   -0.276769
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(x = df["Alcalinity"], y = df["Alcohol"])
plt.xlabel("Alcalinity")
plt.ylabel("Alcohol")
plt.show()

# %%
plt.boxplot(df["Type"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1da71d61d50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1da71d62290>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1da71d61ab0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1da71d627d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1da71d62a70>],
#  'means': []}

# %%
import matplotlib.pyplot as plt
plt.scatter(x = df["Alcohol"], y = df["Type"])
plt.xlabel("Alcohol")
plt.ylabel("Type")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Type             178 non-null    int64
#  1   Alcohol          178 non-null    float64
#  2   Malic            178 non-null    float64
#  3   Ash              178 non-null    float64
#  4   Alcalinity       178 non-null    float64
#  5   Magnesium        178 non-null    int64
#  6   Phenols          178 non-null    float64
#  7   Flavanoids       178 non-null    float64
#  8   Nonflavanoids    178 non-null    float64
#  9   Proanthocyanins  178 non-null    float64
#  10  Color            178 non-null    float64
#  11  Hue              178 non-null    float64
#  12  Dilution         178 non-null    float64
#  13  Proline          178 non-null    int64
# dtypes: float64(11), int64(3)
# memory usage: 19.6 KB

# %%
x = df.iloc[:,1:14]
x.head()
# Out:
#    Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4    13.24   2.59  2.87        21.0        118     2.80        2.69
#
#    Nonflavanoids  Proanthocyanins  Color   Hue  Dilution  Proline
# 0           0.28             2.29   5.64  1.04      3.92     1065
# 1           0.26             1.28   4.38  1.05      3.40     1050
# 2           0.30             2.81   5.68  1.03      3.17     1185
# 3           0.24             2.18   7.80  0.86      3.45     1480
# 4           0.39             1.82   4.32  1.04      2.93      735

# %%
y = df["Type"]
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 173    3
# 174    3
# 175    3
# 176    3
# 177    3
# Name: Type, Length: 178, dtype: int64

# %% [markdown]
# ## Data Transformation

# %%
from sklearn.preprocessing import StandardScaler
s = StandardScaler()
sx = s.fit_transform(x)
x = pd.DataFrame(sx)
x.columns = list(x)
x.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  1.518613 -0.562250  0.232053 -1.169593  1.913905  0.808997  1.034819
# 1  0.246290 -0.499413 -0.827996 -2.490847  0.018145  0.568648  0.733629
# 2  0.196879  0.021231  1.109334 -0.268738  0.088358  0.808997  1.215533
# 3  1.691550 -0.346811  0.487926 -0.809251  0.930918  2.491446  1.466525
# 4  0.295700  0.227694  1.840403  0.451946  1.281985  0.808997  0.663351
#
#          7         8         9         10        11        12
# 0 -0.659563  1.224884  0.251717  0.362177  1.847920  1.013009
# 1 -0.820719 -0.544721 -0.293321  0.406051  1.113449  0.965242
# 2 -0.498407  2.135968  0.269020  0.318304  0.788587  1.395148
# 3 -0.981875  1.032155  1.186068 -0.427544  1.184071  2.334574
# 4  0.226796  0.401404 -0.319276  0.362177  0.449601 -0.037874

# %% [markdown]
# ## Applying Principal Component Analysis

# %%
from sklearn.decomposition import PCA
pc= PCA()
x1 = pc.fit_transform(x)
x= pd.DataFrame(x1)
x.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  3.316751 -1.443463 -0.165739 -0.215631  0.693043 -0.223880  0.596427
# 1  2.209465  0.333393 -2.026457 -0.291358 -0.257655 -0.927120  0.053776
# 2  2.516740 -1.031151  0.982819  0.724902 -0.251033  0.549276  0.424205
# 3  3.757066 -2.756372 -0.176192  0.567983 -0.311842  0.114431 -0.383337
# 4  1.008908 -0.869831  2.026688 -0.409766  0.298458 -0.406520  0.444074
#
#          7         8         9         10        11        12
# 0  0.065139  0.641443  1.020956 -0.451563  0.540810 -0.066239
# 1  1.024416 -0.308847  0.159701 -0.142657  0.388238  0.003637
# 2 -0.344216 -1.177834  0.113361 -0.286673  0.000584  0.021717
# 3  0.643593  0.052544  0.239413  0.759584 -0.242020 -0.369484
# 4  0.416700  0.326819 -0.078366 -0.525945 -0.216664 -0.079364

# %%
x[0].var()
# Out:
# 4.732436977583587

# %%
x[12].var()
# Out:
# 0.10396199182075326

# %%
x1 = pd.DataFrame(pc.explained_variance_ratio_) #Variance of each column
x1
# Out:
#            0
# 0   0.361988
# 1   0.192075
# 2   0.111236
# 3   0.070690
# 4   0.065633
# 5   0.049358
# 6   0.042387
# 7   0.026807
# 8   0.022222
# 9   0.019300
# 10  0.017368
# 11  0.012982
# 12  0.007952

# %%
x = x.iloc[:,0:3] #Selecting only 3 principal components for cluster formation
x
# Out:
#             0         1         2
# 0    3.316751 -1.443463 -0.165739
# 1    2.209465  0.333393 -2.026457
# 2    2.516740 -1.031151  0.982819
# 3    3.757066 -2.756372 -0.176192
# 4    1.008908 -0.869831  2.026688
# ..        ...       ...       ...
# 173 -3.370524 -2.216289 -0.342570
# 174 -2.601956 -1.757229  0.207581
# 175 -2.677839 -2.760899 -0.940942
# 176 -2.387017 -2.297347 -0.550696
# 177 -3.208758 -2.768920  1.013914
#
# [178 rows x 3 columns]

# %% [markdown]
# ### Construction of Dendogram

# %%
import scipy.cluster.hierarchy as shc
import matplotlib.pyplot as plt
plt.figure(figsize=(10,7))
plt.title("Dendogram")
dend = shc.dendrogram(shc.linkage(x, method='ward'))

# %% [markdown]
# ## Agglomeartive Clustering

# %%
from sklearn.cluster import AgglomerativeClustering
cluster = AgglomerativeClustering(n_clusters=3,  linkage='ward')

y = cluster.fit_predict(x)

y_new = pd.DataFrame(y)
y_new[0].value_counts() # number of data points in each cluster
# Out:
# 0    66
# 2    65
# 1    47
# Name: 0, dtype: int64

# %%
df["Type"].value_counts()
# Out:
# 2    71
# 1    59
# 3    48
# Name: Type, dtype: int64

# %% [markdown]
# ## KMeans Clustering

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters = 3)
y = kmeans.fit_predict(x)
y
y_new = pd.DataFrame(y)
y_new[0].value_counts()
# Out:
# F:\ANACONDA SABA\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# F:\ANACONDA SABA\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# 2    65
# 0    62
# 1    51
# Name: 0, dtype: int64

# %%
kmeans.inertia_
# Out:
# 513.0564645910774

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)


kinertiaresults = []
for i in range(1,11):
    kmeans = KMeans(n_clusters =i)
    kmeans.fit_predict(x)
    kinertiaresults.append(kmeans.inertia_)
kinertiaresults
# Out:
# F:\ANACONDA SABA\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# F:\ANACONDA SABA\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# F:\ANACONDA SABA\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ...

# %% [markdown]
# ## Elbow Method

# %%
import matplotlib.pyplot as plt
plt.scatter(x=range(1,11),y=kinertiaresults)
plt.plot(range(1,11), kinertiaresults,color="red")
plt.xlabel("Number of Clusters")
plt.ylabel("k_Inertia")
plt.show()

# %% [markdown]
# #### Hence, from above elbow plot  we can conclude that optimum number of clusters are 3.
